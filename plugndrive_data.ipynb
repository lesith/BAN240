# %%
import pandas as pd
# Out:
#        Make                      Model_Version Electric_Range Total_Range  \
# 0       Kia             Niro Plug-In Hybrid EX          55 km      836 km
# 1      Fiat                500e Red Edition EV            NaN      227 km
# 2    Toyota                     Prius Prime SE          72 km      962 km
# 3    Nissan                            LEAF SV            NaN      240 km
# 4       Kia          Sorento Plug-In Hybrid EX          51 km      681 km
# ..      ...                                ...            ...         ...
# 152   Volvo                  S90 Recharge Plus          61 km      809 km
# 153   Volvo   V60 Recharge Polestar Engineered          64 km      856 km
# 154   Volvo  XC60 Recharge Polestar Engineered          58 km      896 km
# 155   Volvo  XC60 Recharge Ultra Black Edition          58 km      896 km
# 156   Volvo                XC90 Recharge Ultra          53 km      856 km
#
#     Incentives     MSRP Match_Score  \
# 0       $5,000  $38,595     94 /100
# ...

# %%
plugndrive_electric_car_listings = pd.read_csv('plugndrive_electric_car_listings.csv', sep = ',')
plugndrive_electric_car_listings = plugndrive_electric_car_listings.drop(columns=['Vehicle_URL', "Match_Score"])

# %%
plugndrive_electric_car_listings
# Out:
#        Make                      Model_Version Electric_Range Total_Range  \
# 0       Kia             Niro Plug-In Hybrid EX          55 km      836 km
# 1      Fiat                500e Red Edition EV            NaN      227 km
# 2    Toyota                     Prius Prime SE          72 km      962 km
# 3    Nissan                            LEAF SV            NaN      240 km
# 4       Kia          Sorento Plug-In Hybrid EX          51 km      681 km
# ..      ...                                ...            ...         ...
# 152   Volvo                  S90 Recharge Plus          61 km      809 km
# 153   Volvo   V60 Recharge Polestar Engineered          64 km      856 km
# 154   Volvo  XC60 Recharge Polestar Engineered          58 km      896 km
# 155   Volvo  XC60 Recharge Ultra Black Edition          58 km      896 km
# 156   Volvo                XC90 Recharge Ultra          53 km      856 km
#
#     Incentives     MSRP
# 0       $5,000  $38,595
# 1       $5,000  $39,995
# ...

# %%
plugndrive_electric_car_listings.to_csv("cleaned_plugndrive_listings.csv", index=False)

# %%
vehicles_data = pd.read_csv('vehicles_data.csv', sep = ',')
vehicles_data = vehicles_data.drop(columns=['type', 'availability', 'images', 'incentives', 'electric_vehicle_id', 'fossil_fuel_vehicle_id', 'available_for_purchase_as_new', 'epa_id', 'fuel_id', 'custom_price', 'official_website_url', 'eligible_for_ca_rebate', 'eligible_for_ca_hov', 'san_joaquin_valley_ev_rebate', 'video_reviews', 'equivalent_gas_vehicle', 'legal_info'])

# %%
vehicles_data
# Out:
#                                                 handle        make  \
# 0                     Acura_ZDX_A-Spec_AWD_BEV_2024_CA       Acura
# 1                         Acura_ZDX_Type_S_BEV_2024_CA       Acura
# 2                       Alfa_Romeo_Tonale_PHEV_2024_CA  Alfa Romeo
# 3                Alfa_Romeo_Tonale_Veloce_PHEV_2024_CA  Alfa Romeo
# 4                           Audi_e-tron_GT_BEV_2024_CA        Audi
# ..                                                 ...         ...
# 159         Volvo_XC40_Recharge_Twin_Motor_BEV_2024_CA       Volvo
# 160                   Volvo_XC60_Recharge_PHEV_2025_CA       Volvo
# 161  Volvo_XC60_Recharge_Polestar_Engineered_PHEV_2...       Volvo
# 162     Volvo_XC60_Recharge_Black_Edition_PHEV_2025_CA       Volvo
# 163                   Volvo_XC90_Recharge_PHEV_2025_CA       Volvo
#
#              model                          trim  fuel    msrp  doors  \
# 0              ZDX                        A-Spec   BEV   84990      4
# ...

# %%
vehicles_data.to_csv("cleaned_plugndrive_vehicles_data.csv", index=False)

# %%
chargers_data = pd.read_csv('chargers_data.csv', sep = ',')
chargers_data = chargers_data.drop(columns=['charger_id', 'price_src', 'details_link', 'spec_src', 'img', 'discount_value', 'discount_code', 'incentives'])

# %%
chargers_data
# Out:
#                   model        make    model_variant  price  amps  \
# 0                HCS-40     Enphase              NaN    732  32.0
# 1                HCS-40     Enphase                P    648  32.0
# 2                LCS-20     Enphase                P    336  16.0
# 3                HCS-50     Enphase              NaN    809  40.0
# 4                HCS-60     Enphase              NaN   1099  48.0
# ..                  ...         ...              ...    ...   ...
# 211  Residential Series  ZEF Energy     ZEFNET-100-C   4274  80.0
# 212          Pro Series  ZEF Energy    ZEFNET-40-PRO   9075  32.0
# 213          Pro Series  ZEF Energy    ZEFNET-60-PRO   9855  48.0
# 214          Pro Series  ZEF Energy    ZEFNET-80-PRO  10325  64.0
# 215      Power K-Series  ZEF Energy  Movable Charger  28336   NaN
#
#       form_factor  cord_length         home_outlet    plug_types   wifi  \
# 0    Wall mounted           25           Hardwired         J1772  False
# ...

# %%
chargers_data.to_csv("cleaned_plugndrive_chargers_data.csv", index=False)
